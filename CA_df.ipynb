# %%
import pandas as pd

# %%
# Create dataframe for Californa

csv_path = "CAserial5ormore.csv"
CAserial5ormore_df = pd.read_csv(csv_path)
CAserial5ormore_df.head()
# Out:
#    ID                   Name  \
# 0  14   Alcala, Rodney James
# 1  25  Anderson, Allen Leroy
# 2  36  Archerd, William Dale
# 3  49          Atkins, Susan
# 4  91    Bianchi, Kenneth A.
#
#                                                Alias PrisonNum  \
# 0                                                NaN    C18300
# 1                                                NaN    101147
# 2                                                NaN       NaN
# 3                                                NaN    WO8304
# 4  Walker, Steve; Billy; Ish; DAmato, Anthony A.;...    266961
#
#                           PrisonState KilrType  Sex  Race  WhiteMale  \
# 0                    CA - San Quentin   Serial    1     1        1.0
# 1                                 NaN   Serial    1     1        1.0
# 2                                 NaN   Serial    1     1        1.0
# 3                                  CA   Serial    2     1        0.0
# ...
