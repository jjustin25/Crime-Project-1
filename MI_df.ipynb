# %%
import pandas as pd

# %%
# Dataframe for Michigan

csv_path = "MIserial.csv"
MI_serial_df = pd.read_csv(csv_path)
MI_serial_df.head()
# Out:
#    ID                  Name                 Alias        PrisonNum  \
# 0   4      Abuelazam, Elias  Eli, Elias Abullazam           842658
# 1  24    Amos, Lowell Edwin                   NaN           252661
# 2  41  Armstrong, John Eric                   NaN  362407-2084912M
# 3  47      Atkins, Benjamin                   NaN           237134
# 4  73          Beck, Martha                   NaN              NaN
#
#                PrisonState KilrType  Sex  Race  WhiteMale  WhiteMale20s  \
# 0                      NaN   Serial  1.0   1.0        1.0           0.0
# 1                      NaN   Serial  1.0   1.0        1.0           0.0
# 2  MI- Michigan Reformaory   Serial  1.0   1.0        1.0           0.0
# 3                      NaN   Serial  1.0   2.0        0.0           0.0
# 4                      NaN   Serial  2.0   1.0        0.0           0.0
#
#      ...      OtherTotem 2020 BodyWater BodySunk YrsSent  DobbertPri  \
# ...
