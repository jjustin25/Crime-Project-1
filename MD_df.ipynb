# %%
import pandas as pd

# %%
# Dataframe for Maryland

csv_path = "MDSerial.csv"
MD_serial_df = pd.read_csv(csv_path, encoding = "ISO-8859-1")
MD_serial_df.head()
# Out:
#     ID                       Name  \
# 0  111      Bolding, Jane Francis
# 1  120           Bowles, Gary Ray
# 2  186    Cannon, Martha Patricia
# 3  222  Christenson, William Dean
# 4  228           Clark, Hadden I.
#
#                                                Alias  PrisonNum  \
# 0                                                NaN        NaN
# 1  Whitfield, Timothy; Boles, Gary Ray; Bowles, M...    86158.0
# 2                                   Cannon, Lucretia        NaN
# 3                                                NaN        NaN
# 4                                                NaN   233181.0
#
#        PrisonState KilrType  Sex  Race  WhiteMale  WhiteMale20s    ...      \
# 0              NaN   Serial    2   1.0        0.0             0    ...
# 1  FL - UNION C.I.   Serial    1   1.0        1.0             0    ...
# 2              NaN   Serial    2   1.0        0.0             0    ...
# 3              NaN   Serial    1   1.0        1.0             0    ...
# ...
