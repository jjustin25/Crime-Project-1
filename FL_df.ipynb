# %%
import pandas as pd

# %%
# Dataframe for Florida

csv_path = "FLASerial.csv"
FLA_serial_df = pd.read_csv(csv_path)
FLA_serial_df.head()
# Out:
#    ID                   Name                                          Alias  \
# 0   2      Ables, Tony Alvin  THADAISIS GORDON, MICHAEL JONES, JAMES SELBEY
# 1  25  Anderson, Allen Leroy                                            NaN
# 2  59     Rode, Adolph James                                  Barone, Cesar
# 3  77       Bell, Larry Gene                                            NaN
# 4  78  Bell, Michael Bernard                                            NaN
#
#        PrisonNum      PrisonState KilrType  Sex  Race  WhiteMale  \
# 0  29850, 029850   FL - LAKE C.I.   Serial    1     2        0.0
# 1         101147              NaN   Serial    1     1        1.0
# 2            NaN              NaN   Serial    1     1        1.0
# 3          39872              NaN   Serial    1     1        1.0
# 4         108426  FL - UNION C.I.   Serial    1     2        0.0
#
#    WhiteMale20s    ...      OtherTotem 2020 BodyWater BodySunk   YrsSent  \
# ...
