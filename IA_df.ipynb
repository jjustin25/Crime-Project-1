# %%
import pandas as pd

# %%
# Dataframe for Iowa

csv_path = "IASerial.csv"
IA_serial_df = pd.read_csv(csv_path, encoding = "ISO-8859-1")
IA_serial_df.head()
# Out:
#      ID                   Name Alias  PrisonNum                   PrisonState  \
# 0   521  Nelson, Earle Leonard   NaN        NaN                           NaN
# 1   582   Jordan, Gilbert Paul   NaN        NaN                           NaN
# 2   770    Kinney, James Allen   NaN        NaN                           NaN
# 3   996   Piper, Donald Arthur   NaN  1153862.0  IA - Iowa State Penitentiary
# 4  1026     Race, Glen Douglas   NaN        NaN                           NaN
#
#   KilrType  Sex  Race  WhiteMale  WhiteMale20s    ...      OtherTotem 2020  \
# 0   Serial    1     1        1.0           1.0    ...               0    0
# 1   Serial    1     1        1.0           0.0    ...               0    0
# 2   Serial    1     1        1.0           0.0    ...               0    0
# 3   Serial    1     1        1.0           0.0    ...               0    0
# 4   Serial    1     1        1.0           1.0    ...               0    0
#
# ...
