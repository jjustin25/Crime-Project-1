# %%
import pandas as pd

# %%
# Dataframe for Kansas

csv_path = "KSSerial.csv"
KS_serial_df = pd.read_csv(csv_path)
KS_serial_df.head()
# Out:
#     ID                      Name                                   Alias  \
# 0  128      Braun, Gregg Francis                                     NaN
# 1  346         Doss, Nancy Hazle  Doss, Nanny; Hazle Nancy; Hazel, Nancy
# 2  425        Floyd, Cecil Henry                                     NaN
# 3  523  Nemechek, Francis Donald                                     NaN
# 4  525       Guatney, William J.                                     NaN
#
#    PrisonNum PrisonState KilrType  Sex  Race  WhiteMale  WhiteMale20s  \
# 0        NaN         NaN   Serial    1   1.0        1.0           1.0
# 1        NaN         NaN   Serial    2   1.0        0.0           0.0
# 2     5271.0         NaN   Serial    1   1.0        1.0           0.0
# 3        NaN         NaN   Serial    1   1.0        1.0           1.0
# 4        NaN         NaN   Serial    1   1.0        1.0           0.0
#
#      ...      OtherTotem 2020 BodyWater BodySunk YrsSent  DobbertPri  \
# ...
