# %%
import pandas as pd

# %%
# Dataframe for Illinois

csv_path = "ILSerial.csv"
IL_serial_df = pd.read_csv(csv_path, encoding = "ISO-8859-1")
IL_serial_df.head()
# Out:
#    ID                    Name Alias PrisonNum                PrisonState  \
# 0  12    Albanese, Charles M.   NaN       NaN                        NaN
# 1  16             Allen, Bill   NaN       NaN                        NaN
# 2  27       Anderson, Dale R.   NaN    B06156  IL - Pontiac Correctional
# 3  33  Andrews, Ralph Raymond   NaN       NaN                        NaN
# 4  67     Baughman, John Earl   NaN       NaN                        NaN
#
#   KilrType  Sex  Race  WhiteMale  WhiteMale20s    ...      OtherTotem 2020  \
# 0   Serial    1     1          1           0.0    ...               0    0
# 1   Serial    1     2          0           0.0    ...               0    0
# 2   Serial    1     1          1           0.0    ...               0    0
# 3   Serial    1     1          1           1.0    ...               0    0
# 4   Serial    1     1          1           1.0    ...               0    0
#
#   BodyWater BodySunk YrsSent  DobbertPri  DobbertSec PartnerID  \
# ...
