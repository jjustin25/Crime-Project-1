# %%
import pandas as pd

# %%
# Dataframe for Georgia

csv_path = "GASerial.csv"
GA_serial_df = pd.read_csv(csv_path)
GA_serial_df.head()
# Out:
#    ID                          Name  \
# 0  11            Akin, Joseph Dewey
# 1  15  Allanson, Patricia Radcliffe
# 2  54             Bankston, Clinton
# 3  75        Belcher, Howard Milton
# 4  96            Birt, Billy Sunday
#
#                                                Alias   PrisonNum  \
# 0                                                NaN         NaN
# 1  Taylor, Patricia; TAYLOR,MARY RADCLIFF; ALLISO...  0000394526
# 2                                                NaN  0000468785
# 3                                                NaN     1076495
# 4                                                NaN      403007
#
#                  PrisonState KilrType  Sex  Race  WhiteMale  WhiteMale20s  \
# 0                        NaN   Serial  1.0   1.0        1.0           0.0
# 1  GA - Pulaski State Prison   Serial  2.0   1.0        0.0           0.0
# 2    GA - DOOLY STATE PRISON   Serial  1.0   2.0        0.0           0.0
# ...
