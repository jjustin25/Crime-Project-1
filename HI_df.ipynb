# %%
import pandas as pd

# %%
# Dataframe for Hawaii

csv_path = "HISerial.csv"
HI_serial_df = pd.read_csv(csv_path)
HI_serial_df.head()
# Out:
#      ID                  Name  Alias        PrisonNum  \
# 0    41  Armstrong, John Eric    NaN  362407-2084912M
# 1  1430      Bartsch, Juergen    NaN              NaN
# 2  1435    Beck, Ernst Dieter    NaN              NaN
# 3  1455         Black, Robert    NaN              NaN
# 4  1464         Boost, Werner    NaN              NaN
#
#                PrisonState KilrType  Sex  Race  WhiteMale  WhiteMale20s  \
# 0  MI- Michigan Reformaory   Serial    1     1          1           0.0
# 1                      NaN   Serial    1     1          1           0.0
# 2                      NaN   Serial    1     1          1           1.0
# 3                      NaN   Serial    1     1          1           0.0
# 4                      NaN   Serial    1     1          1           1.0
#
#      ...      OtherTotem 2020 BodyWater BodySunk YrsSent  DobbertPri  \
# 0    ...               0    0       0.0      0.0     NaN         NaN
# ...
